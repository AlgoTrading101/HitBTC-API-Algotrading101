# %%
import requests
import time
session = requests.session()


def get_trades(symbol_code, from_id):
    return session.get("https://api.hitbtc.com/api/2/public/trades/%s?sort=ASC&by=id&from=%d&limit=1000" % (symbol_code, from_id)).json()


symbol = 'BTCUSD'
from_trade_id = 1

while True:
    trades = get_trades(symbol, from_trade_id)
    if len(trades) > 0:
        from_trade_id = trades[-1]['id'] + 1
        print('Loaded trades until', trades[-1]['id'], trades[-1]['timestamp'])
        if len(trades) < 1000:
            time.sleep(5)
    else:
        time.sleep(30)
# Out:
# Loaded trades until 1000 2013-12-27T19:18:50.140Z
# Loaded trades until 2000 2013-12-27T22:05:49.659Z
# Loaded trades until 3000 2013-12-28T00:45:51.339Z
# Loaded trades until 4000 2013-12-28T03:51:30.530Z
# Loaded trades until 5000 2013-12-28T06:43:04.665Z
# Loaded trades until 6000 2013-12-28T09:31:10.264Z
# Loaded trades until 7000 2013-12-28T12:21:57.225Z
# Loaded trades until 8000 2013-12-28T15:22:14.264Z
# Loaded trades until 9000 2013-12-28T18:03:43.146Z
# Loaded trades until 10000 2013-12-28T20:49:53.226Z
# Loaded trades until 11000 2013-12-28T23:46:06.826Z
# Loaded trades until 12000 2013-12-29T02:43:43.190Z
# Loaded trades until 13000 2013-12-29T05:41:18.791Z
# Loaded trades until 14000 2013-12-29T08:31:56.230Z
# Loaded trades until 15000 2013-12-29T11:17:53.591Z
# Loaded trades until 16000 2013-12-29T14:02:43.508Z
# Loaded trades until 17000 2013-12-29T16:48:38.473Z
# Loaded trades until 18000 2013-12-29T19:29:26.312Z
# Loaded trades until 19000 2013-12-29T22:06:57.272Z
# ...
